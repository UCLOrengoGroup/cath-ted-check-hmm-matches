# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from domain_vis.domain_vis_luck import visualize_domains_and_plot

# %%
df = pd.read_csv("data/luck_analyses_human/luck_results.tsv", sep = "\t", header = None)
df.columns = ['chain_id', 'ted_id', 'HMM-superfamily', 'TED-superfamily', 'hmm_evalue', 'overlap_percentage', 'hmm_boundaries', 'foldseek_boundaries', 's95-HMM-superfamily']
df['match'] = df.apply(lambda row: 'match' if row['HMM-superfamily'] == row['TED-superfamily'] else 'no match', axis=1)
df.head()
# Out:
#                 chain_id                       ted_id HMM-superfamily  \
# 0  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED01     3.10.20.230
# 1  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED02     3.10.20.230
# 2  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED03     3.10.20.230
# 3  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED07      2.80.10.50
# 4  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED09     3.10.20.230
#
#   TED-superfamily    hmm_evalue  overlap_percentage hmm_boundaries  \
# 0     3.10.20.230  4.500000e-04               96.30        173-253
# 1     3.10.20.230  8.100000e-04                0.00      1397-1486
# 2     3.10.20.230  8.100000e-04                0.00      1397-1486
# 3      2.80.10.50  1.200000e-04               67.09      1141-1267
# 4     3.10.20.230  6.400000e-07               63.20      1631-1755
#
#    foldseek_boundaries s95-HMM-superfamily  match
# 0              175-252             2dnfA01  match
# ...

# %%
df2 = pd.read_csv("data/luck_analyses_human/all_luck_domains_in_ted", sep='\s', header= None)
df2 = df2[[0, 6, 16]]
df2.columns = ['ted_id', 'plddt', 'packing_density']
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/n4/sdx4zvks1m76mtqqpm6rw32w0000gn/T/ipykernel_5782/431429933.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df2 = pd.read_csv("data/luck_analyses_human/all_luck_domains_in_ted", sep='\s', header= None)
# /var/folders/n4/sdx4zvks1m76mtqqpm6rw32w0000gn/T/ipykernel_5782/431429933.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df2 = pd.read_csv("data/luck_analyses_human/all_luck_domains_in_ted", sep='\s', header= None)

# %%
df = pd.merge(df, df2, on='ted_id', how='left')
df.head()
# Out:
#                 chain_id                       ted_id HMM-superfamily  \
# 0  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED01     3.10.20.230
# 1  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED02     3.10.20.230
# 2  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED03     3.10.20.230
# 3  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED07      2.80.10.50
# 4  AF-M0R2J8-F1-model_v4  AF-M0R2J8-F1-model_v4_TED09     3.10.20.230
#
#   TED-superfamily    hmm_evalue  overlap_percentage hmm_boundaries  \
# 0     3.10.20.230  4.500000e-04               96.30        173-253
# 1     3.10.20.230  8.100000e-04                0.00      1397-1486
# 2     3.10.20.230  8.100000e-04                0.00      1397-1486
# 3      2.80.10.50  1.200000e-04               67.09      1141-1267
# 4     3.10.20.230  6.400000e-07               63.20      1631-1755
#
#    foldseek_boundaries s95-HMM-superfamily  match    plddt  packing_density
# ...

# %%
visualize_domains_and_plot(df)
